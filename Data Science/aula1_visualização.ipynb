# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # TMDB 5000 Movies

# %%
tmdb = pd.read_csv('dados/tmdb_5000_movies.csv')

# %%
tmdb.original_language.describe()
# Out:
# count     4803
# unique      37
# top         en
# freq      4505
# Name: original_language, dtype: object

# %%
lingua_original_filmes = tmdb.original_language.value_counts().to_frame().reset_index()
lingua_original_filmes.columns = ['language', 'total']

# %%
lingua_original_filmes
# Out:
#    language  total
# 0        en   4505
# 1        fr     70
# 2        es     32
# 3        zh     27
# 4        de     27
# 5        hi     19
# 6        ja     16
# 7        it     14
# 8        cn     12
# 9        ru     11
# 10       ko     11
# 11       pt      9
# 12       da      7
# 13       sv      5
# 14       nl      4
# 15       fa      4
# 16       th      3
# 17       he      3
# 18       ta      2
# 19       cs      2
# 20       ro      2
# 21       id      2
# 22       ar      2
# 23       vi      1
# 24       sl      1
# 25       ps      1
# 26       no      1
# 27       ky      1
# 28       hu      1
# 29       pl      1
# 30       af      1
# 31       nb      1
# 32       tr      1
# 33       is      1
# 34       xx      1
# 35       te      1
# 36       el      1

# %%
#Neste caso, como há discrepância muito grande entre a primeira língua e todas as demais, é preciso fugir desse tipo de visualização
sns.barplot(x="language", y="total", data=lingua_original_filmes)
# Out:
# <AxesSubplot:xlabel='language', ylabel='total'>

# %%
sns.catplot(x="original_language", kind="count", data=tmdb)

# %%
#Não representa a melhor leitura
plt.pie(lingua_original_filmes['total'], labels=lingua_original_filmes['language'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7efd355db1f0>,
#   <matplotlib.patches.Wedge at 0x7efd355db730>,
#   <matplotlib.patches.Wedge at 0x7efd355dbc10>,
#   <matplotlib.patches.Wedge at 0x7efd355e9130>,
#   <matplotlib.patches.Wedge at 0x7efd355e9610>,
#   <matplotlib.patches.Wedge at 0x7efd355e9af0>,
#   <matplotlib.patches.Wedge at 0x7efd355e9fd0>,
#   <matplotlib.patches.Wedge at 0x7efd355f74f0>,
#   <matplotlib.patches.Wedge at 0x7efd355f79d0>,
#   <matplotlib.patches.Wedge at 0x7efd355f7eb0>,
#   <matplotlib.patches.Wedge at 0x7efd356b9520>,
#   <matplotlib.patches.Wedge at 0x7efd35584880>,
#   <matplotlib.patches.Wedge at 0x7efd35584d60>,
#   <matplotlib.patches.Wedge at 0x7efd35591280>,
#   <matplotlib.patches.Wedge at 0x7efd35591760>,
#   <matplotlib.patches.Wedge at 0x7efd35591c40>,
#   <matplotlib.patches.Wedge at 0x7efd3559e160>,
#   <matplotlib.patches.Wedge at 0x7efd3559e640>,
#   <matplotlib.patches.Wedge at 0x7efd3559eb20>,
#   <matplotlib.patches.Wedge at 0x7efd3559efd0>,
#   <matplotlib.patches.Wedge at 0x7efd355ac520>,
#   <matplotlib.patches.Wedge at 0x7efd355aca00>,
#   <matplotlib.patches.Wedge at 0x7efd355acee0>,
#   <matplotlib.patches.Wedge at 0x7efd355b7400>,
#   <matplotlib.patches.Wedge at 0x7efd355b78e0>,
#   <matplotlib.patches.Wedge at 0x7efd355b7dc0>,
#   <matplotlib.patches.Wedge at 0x7efd355462e0>,
#   <matplotlib.patches.Wedge at 0x7efd355467c0>,
#   <matplotlib.patches.Wedge at 0x7efd35546ca0>,
#   <matplotlib.patches.Wedge at 0x7efd355541c0>,
#   <matplotlib.patches.Wedge at 0x7efd355546a0>,
#   <matplotlib.patches.Wedge at 0x7efd35554b80>,
#   <matplotlib.patches.Wedge at 0x7efd355620a0>,
#   <matplotlib.patches.Wedge at 0x7efd35562580>,
#   <matplotlib.patches.Wedge at 0x7efd35562a60>,
#   <matplotlib.patches.Wedge at 0x7efd35562f40>,
#   <matplotlib.patches.Wedge at 0x7efd3556f460>],
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
#   Text(1.0992355702663055, -0.04100196411527794, 'th'),
#   Text(1.0993880184234357, -0.03668766750546649, 'he'),
#   Text(1.0995021239019234, -0.033091985965784415, 'ta'),
#   Text(1.099584941078101, -0.03021518416739545, 'cs'),
#   Text(1.0996602312343366, -0.027338175536150495, 'ro'),
#   Text(1.099727993855245, -0.024460979766119193, 'id'),
#   Text(1.0997882284769684, -0.02158361655264929, 'ar'),
#   Text(1.0998284639438185, -0.01942549610642471, 'vi'),
#   Text(1.0998529348820232, -0.01798670707495573, 'sl'),
#   Text(1.0998755236058106, -0.01654788726224571, 'ps'),
#   Text(1.0998962300765243, -0.01510903913059323, 'no'),
#   Text(1.0999150542587282, -0.013670165142345335, 'ky'),
#   Text(1.0999319961202083, -0.012231267759896247, 'hu'),
#   Text(1.0999470556319713, -0.01079234944567632, 'pl'),
#   Text(1.099960232768245, -0.00935341266215563, 'af'),
#   Text(1.0999715275064792, -0.007914459871831963, 'nb'),
#   Text(1.0999809398273452, -0.006475493537234394, 'tr'),
#   Text(1.0999884697147349, -0.005036516120911278, 'is'),
#   Text(1.0999941171557621, -0.0035975300854338356, 'xx'),
#   Text(1.0999978821407626, -0.0021585378933851127, 'te'),
#   Text(1.0999997646632929, -0.0007195420073586872, 'el')])

# %% [markdown]
# ### Top 3 Línguas mais utilizadas no cinema

# %%
linguas_mais_comuns = lingua_original_filmes.query('total > 30')

# %%
sns.barplot(x="language", y="total", data=linguas_mais_comuns)
# Out:
# <AxesSubplot:xlabel='language', ylabel='total'>

# %% [markdown]
# ### Filmes em inglês dominam o mercado

# %%
total_por_lingua = tmdb['original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_ingles = total_por_lingua.loc['en']
total_do_resto = total_geral - total_ingles
print(total_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'language': ['english', 'others'],
    'total': [total_ingles, total_do_resto]
}
dados
# Out:
# {'language': ['english', 'others'], 'total': [4505, 298]}

# %%
pd.DataFrame(dados)
# Out:
#   language  total
# 0  english   4505
# 1   others    298

# %%
sns.barplot(x='language', y='total', data=dados)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Filmes em outras línguas

# %%
outras_linguas = tmdb.query("original_language != 'en'")

# %%
total_outras_linguas = tmdb.query("original_language != 'en'").original_language.value_counts()

# %%
#Formatado para facilitar a leitura e interpretação dos dados
sns.catplot(x="original_language", 
            data=outras_linguas, 
            kind="count", 
            aspect=2, 
            palette="GnBu_d",
            order=total_outras_linguas.index)

# %%
#Formatação original do seaborn, que não apresenta os dados da melhor maneira:
sns.catplot(x="original_language", 
            data=outras_linguas, 
            kind="count")

# %% [markdown]
# # Resumo da análise dos 5000 filmes da coleção:

# %% [markdown]
# ### A grande maioria dos filmes lançados é em inglês

# %%
sns.barplot(x='language', y='total', data=dados)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Francês e espanhol ocupam segundo e terceiro lugares entre as linguas originais dos filmes, ainda que bem aquém da primeira posição (inglês). A partir do 5º lugar há uma pulverização maior e em menor grau de importância

# %%
sns.catplot(x="original_language", 
            data=outras_linguas, 
            kind="count", 
            aspect=2, 
            palette="GnBu_d",
            order=total_outras_linguas.index)
