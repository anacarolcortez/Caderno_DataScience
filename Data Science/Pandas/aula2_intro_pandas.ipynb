# %%
import pandas as pd

# %%
imoveis = pd.read_csv('aluguel/aluguel.csv', sep=';')

# %%
imoveis.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
print(f'A base de dados apresenta {imoveis.shape[0]} registros e {imoveis.shape[1]} colunas')
# Out:
# A base de dados apresenta 32960 registros e 9 colunas

# %%
print('Tipos de dados')
imoveis.dtypes
# Out:
# Tipos de dados
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %% [markdown]
# ### Criando um dataframe

# %%
tipos_de_imoveis = imoveis['Tipo'].drop_duplicates()

# %%
tipos_de_imoveis = pd.DataFrame(tipos_de_imoveis)

# %%
tipos_de_imoveis.index = ["imov" + str(i) for i in range(tipos_de_imoveis.shape[0])]

# %%
tipos_de_imoveis.index.name = "Id"
tipos_de_imoveis
# Out:
#                                Tipo
# Id
# imov0                     Quitinete
# imov1                          Casa
# imov2       Conjunto Comercial/Sala
# imov3                   Apartamento
# imov4            Casa de Condomínio
# imov5                Prédio Inteiro
# imov6                          Flat
# imov7                    Loja/Salão
# imov8       Galpão/Depósito/Armazém
# imov9                Casa Comercial
# imov10                 Casa de Vila
# imov11               Terreno Padrão
# imov12                  Box/Garagem
# imov13                         Loft
# imov14  Loja Shopping/ Ct Comercial
# imov15                      Chácara
# imov16        Loteamento/Condomínio
# imov17                        Sítio
# imov18                Pousada/Chalé
# imov19                       Studio
# imov20                        Hotel
# imov21                    Indústria

# %% [markdown]
# # Imóveis Residenciais

# %%
imoveis_residenciais = imoveis.query("Tipo == 'Quitinete' or Tipo == 'Casa' or Tipo == 'Apartamento' or Tipo == 'Casa de Vila' or Tipo == 'Casa de Condomínio'")

# %%
imoveis_residenciais.index = range(imoveis_residenciais.shape[0])

# %%
imoveis_residenciais.index.name = "Id"

# %%
imoveis_residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# Id
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# Id
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# ### Exportando o resultado para arquivo csv

# %%
imoveis_residenciais.to_csv('aluguel/aluguel_residencial.csv', sep=';', index=False)

# %% [markdown]
# ### Importando nova base de dados

# %%
residenciais = pd.read_csv('aluguel/aluguel_residencial.csv', sep=';')
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# ## Frequência por tipo de imóvel residencial

# %% [markdown]
# #### Apartamento

# %%
apartamentos = residenciais.query("Tipo == 'Apartamento'")
apartamentos
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# 5      Apartamento              Cachambi        2      0       0    50
# 8      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 22573  Apartamento        Vila Valqueire        2      0       0    52
# 22575  Apartamento                 Méier        2      0       0    70
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# ...

# %%
print(f'Total de imóveis residenciais do tipo Apartamento: {apartamentos.shape[0]}')
# Out:
# Total de imóveis residenciais do tipo Apartamento: 19532

# %% [markdown]
# #### Casa

# %%
casas = residenciais.query("Tipo == 'Casa' or Tipo == 'Casa de Vila' or Tipo == 'Casa de Condomínio'")
casas
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 6      Casa de Condomínio          Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                    Ramos        2      2       0
# 14     Casa de Condomínio                  Taquara        3      1       1
# 18     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 22545  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 22547                Casa            Bento Ribeiro        2      1       0
# 22555  Casa de Condomínio          Barra da Tijuca        3      5       3
# 22558                Casa                   Centro        5      0       1
# 22574  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# ...

# %%
print(f'Total de imóveis residenciais do tipo Casa: {casas.shape[0]}')
# Out:
# Total de imóveis residenciais do tipo Casa: 2212

# %% [markdown]
# #### Por área

# %%
de_60_a_100_metros = residenciais.query("Area >= 60 and Area <= 100")
de_60_a_100_metros
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 7      Casa de Condomínio                     Ramos        2      2       0
# 9             Apartamento                    Grajaú        2      1       0
# 10            Apartamento       Lins de Vasconcelos        3      1       1
# ...                   ...                       ...      ...    ...     ...
# 22568         Apartamento  Recreio dos Bandeirantes        3      2       1
# 22570         Apartamento                    Leblon        3      0       1
# 22575         Apartamento                     Méier        2      0       0
# 22577         Apartamento               Jacarepaguá        3      1       2
# 22579         Apartamento                    Leblon        2      0       0
#
#        Area   Valor  Condominio   IPTU
# ...

# %%
print(f'Total de imóveis residenciais com área entre 60 e 100 metros: {de_60_a_100_metros.shape[0]}')
# Out:
# Total de imóveis residenciais com área entre 60 e 100 metros: 8719

# %% [markdown]
# #### Imóveis com 4 quartos ou mais e aluguel abaixo de R$ 2000.00

# %%
selecao = residenciais.query("Quartos >= 4 and Valor < 2000.0")
selecao
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 484           Apartamento  Recreio dos Bandeirantes        4      2       2
# 1003          Apartamento                   Taquara        4      1       1
# 1961                 Casa              Campo Grande        4      1       4
# 2102                 Casa         Engenho de Dentro        4      3       0
# 2200          Apartamento  Recreio dos Bandeirantes        4      2       2
# 2338         Casa de Vila                     Méier        4      0       1
# 3943                 Casa              Campo Grande        4      1       0
# 3944          Apartamento              Campo Grande        4      2       1
# 4349          Apartamento  Recreio dos Bandeirantes        4      2       1
# 5081          Apartamento               Cidade Nova        4      0       0
# 6524          Apartamento                 Pechincha        4      1       2
# ...

# %%
print(f'Total de imóveis residenciais com pelo menos 4 quartos e aluguel abaixo de R$ 2.000: {selecao.shape[0]}')
# Out:
# Total de imóveis residenciais com pelo menos 4 quartos e aluguel abaixo de R$ 2.000: 41

# %% [markdown]
# # Eliminando dados nulos

# %% [markdown]
# ### Valor do aluguel

# %%
residenciais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22580 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
residenciais.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 22575  False   False    False  False   False  False  False       False  False
# 22576  False   False    False  False   False  False  False       False  False
# 22577  False   False    False  False   False  False  False       False  False
# 22578  False   False    False  False   False  False  False       False  False
# 22579  False   False    False  False   False  False  False       False   True
#
# [22580 rows x 9 columns]

# %%
residenciais[residenciais['Valor'].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 58    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1492  Apartamento             Leme        2      0       0    75    NaN
# 1683         Casa     Campo Grande        3      4       3   363    NaN
# 2012  Apartamento         Botafogo        2      0       0    95    NaN
# 2034  Apartamento       Copacabana        2      0       0    72    NaN
# 4941         Casa     Campo Grande        3      2       1   100    NaN
# 8568  Apartamento             Leme        2      0       1    75    NaN
# 8947  Apartamento           Glória        3      0       1   135    NaN
# 9149  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 58         970.0   68.0
# 1492       878.0    NaN
# 1683         NaN    NaN
# 2012      1010.0  170.0
# 2034       850.0    NaN
# 4941         NaN    NaN
# 8568       878.0    NaN
# 8947       910.0  228.0
# ...

# %%
residenciais.dropna(subset=['Valor'], inplace=True)

# %%
print(f'Total: {residenciais.shape[0]}')
# Out:
# Total: 22571

# %% [markdown]
# ### Valor do condomínio

# %%
residenciais[residenciais['Condominio'].isnull()].shape[0]
# Out:
# 1813

# %%
excluir = (residenciais['Tipo'] == 'Apartamento') & (residenciais['Condominio'].isnull())

# %%
residenciais = residenciais[~excluir]

# %%
residenciais[residenciais['Condominio'].isnull()].shape[0]
# Out:
# 1068

# %%
residenciais.fillna(0, inplace=True)
#residenciais = residenciais.fillna({'Condominio': 0, 'IPTU': 0})
# Out:
# /home/ana/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
residenciais[residenciais['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
residenciais[residenciais['IPTU'].isnull()].shape[0]
# Out:
# 0

# %%
residenciais.info
# Out:
# <bound method DataFrame.info of               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# ...

# %% [markdown]
# ### Atualizar base de dados

# %%
residenciais.to_csv('aluguel/aluguel_residencial.csv', sep=';', index=False)

# %%
residenciais = pd.read_csv('aluguel/aluguel_residencial.csv', sep=';')

# %%
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %% [markdown]
# ### Acrescentando variáveis no dataframe

# %%
residenciais['Valor Bruto'] = residenciais['Valor'] + residenciais['Condominio'] + residenciais['IPTU']

# %%
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto
# 0      1700.0       500.0  60.0       2260.0
# ...

# %%
residenciais['Valor m2'] = residenciais['Valor']/residenciais['Area']

# %%
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto   Valor m2
# 0      1700.0       500.0  60.0       2260.0  42.500000
# ...

# %%
residenciais['Valor m2'] = residenciais['Valor m2'].round(2)

# %%
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2
# 0      1700.0       500.0  60.0       2260.0     42.50
# ...

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
residenciais['Tipo Agregado'] = residenciais['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
residenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2 Tipo Agregado
# ...

# %%
# del residenciais['Suites']

# %%
residenciais.pop('Valor Bruto')
# Out:
# 0        2260.0
# 1        7000.0
# 2        1210.0
# 3        1030.0
# 4        1618.0
#           ...
# 21821    1438.0
# 21822    1175.0
# 21823    2640.0
# 21824    1946.0
# 21825    3760.0
# Name: Valor Bruto, Length: 21826, dtype: float64

# %%
#residenciais.drop(['Valor Bruto', 'Valor Bruto m2'], axis = 1, inplace = True)
#excluir mais de uma coluna por vez

# %%
residenciais.to_csv('aluguel/aluguel_residencial.csv', sep=';', index = False)

# %% [markdown]
# ## Agrupamento de dados

# %%
print(f"Valor médio de imóvel residencial: {residenciais['Valor'].mean()}")
# Out:
# Valor médio de imóvel residencial: 5046.172821405663

# %%
residenciais['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4               Cachambi
#               ...
# 13855          Bancários
# 15277         Cavalcanti
# 15280       Rio da Prata
# 15412      Cidade Jardim
# 16428        Coelho Neto
# Name: Bairro, Length: 152, dtype: object

# %%
grupo_bairro = residenciais.groupby('Bairro')

# %%
grupo_bairro

# %%
for bairro, dados in grupo_bairro:
    print(bairro)
# Out:
# Abolição
# Alto da Boa Vista
# Anchieta
# Andaraí
# Anil
# Arpoador
# Bancários
# Bangu
# Barra da Tijuca
# Barra de Guaratiba
# Benfica
# Bento Ribeiro
# Bonsucesso
# Botafogo
# Braz de Pina
# Cachambi
# Cachamorra
# Cacuia
# Caju
# Camorim
# Campinho
# Campo Grande
# Cascadura
# Catete
# Catumbi
# Cavalcanti
# Centro
# Cidade Jardim
# Cidade Nova
# Cocotá
# Coelho Neto
# Colégio
# Copacabana
# Cordovil
# Cosme Velho
# Cosmos
# Curicica
# Del Castilho
# Encantado
# Engenho Novo
# Engenho da Rainha
# Engenho de Dentro
# Estácio
# Flamengo
# Freguesia (Ilha do Governador)
# Freguesia (Jacarepaguá)
# Fátima
# Gamboa
# Gardênia Azul
# Glória
# Grajaú
# Guadalupe
# Guaratiba
# Gávea
# Higienópolis
# Honório Gurgel
# Humaitá
# Icaraí
# Ilha do Governador
# Inhaúma
# Inhoaíba
# Ipanema
# Irajá
# Itanhangá
# Jabour
# Jacarepaguá
# Jacaré
# Jardim América
# Jardim Botânico
# Jardim Carioca
# Jardim Guanabara
# Jardim Oceânico
# Jardim Sulacap
# Joá
# Lagoa
# Lapa
# Laranjeiras
# ...

# %%
for bairro, dados in grupo_bairro: 
    print(f'{bairro} -> {residenciais.Valor.mean()}')
# Out:
# Abolição -> 5046.172821405663
# Alto da Boa Vista -> 5046.172821405663
# Anchieta -> 5046.172821405663
# Andaraí -> 5046.172821405663
# Anil -> 5046.172821405663
# Arpoador -> 5046.172821405663
# Bancários -> 5046.172821405663
# Bangu -> 5046.172821405663
# Barra da Tijuca -> 5046.172821405663
# Barra de Guaratiba -> 5046.172821405663
# Benfica -> 5046.172821405663
# Bento Ribeiro -> 5046.172821405663
# Bonsucesso -> 5046.172821405663
# Botafogo -> 5046.172821405663
# Braz de Pina -> 5046.172821405663
# Cachambi -> 5046.172821405663
# Cachamorra -> 5046.172821405663
# Cacuia -> 5046.172821405663
# Caju -> 5046.172821405663
# Camorim -> 5046.172821405663
# Campinho -> 5046.172821405663
# Campo Grande -> 5046.172821405663
# Cascadura -> 5046.172821405663
# Catete -> 5046.172821405663
# Catumbi -> 5046.172821405663
# Cavalcanti -> 5046.172821405663
# Centro -> 5046.172821405663
# Cidade Jardim -> 5046.172821405663
# Cidade Nova -> 5046.172821405663
# Cocotá -> 5046.172821405663
# ...

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  3966.67      885.00
# Anchieta            875.00       19.75
# Andaraí            1464.71      497.71
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     1769.58      276.88
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]
