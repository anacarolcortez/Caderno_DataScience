# %% [markdown]
# # Métodos de pesquisa com Find

# %%
from bs4 import BeautifulSoup

html = """
<html>
    <body>
        <div id="container-a">
            <h1>Título A</h1>
            <h2 class="ref-a">Sub título A</h2>
            <p>Texto de conteúdo A</p>
        </div>
        <div id="container-b">
            <h1>Título B</h1>
            <h2 class="ref-b">Sub título B</h2>
            <p>Texto de conteúdo B</p>
        </div>
    </body>
</html>
"""

soup = BeautifulSoup(html, 'html.parser')

# %%
soup.find('h2')
# Out:
# <h2 class="ref-a">Sub título A</h2>

# %%
soup.findAll('h2')
# Out:
# [<h2 class="ref-a">Sub título A</h2>, <h2 class="ref-b">Sub título B</h2>]

# %%
soup.findAll('div', id="container-b")
# Out:
# [<div id="container-b">
#  <h1>Título B</h1>
#  <h2 class="ref-b">Sub título B</h2>
#  <p>Texto de conteúdo B</p>
#  </div>]

# %%
soup.find('h2').find_parent('div')
# Out:
# <div id="container-a">
# <h1>Título A</h1>
# <h2 class="ref-a">Sub título A</h2>
# <p>Texto de conteúdo A</p>
# </div>

# %%
for item in soup.findAll('h2'):
    print(item.find_parent('div'))
# Out:
# <div id="container-a">
# <h1>Título A</h1>
# <h2 class="ref-a">Sub título A</h2>
# <p>Texto de conteúdo A</p>
# </div>
# <div id="container-b">
# <h1>Título B</h1>
# <h2 class="ref-b">Sub título B</h2>
# <p>Texto de conteúdo B</p>
# </div>

# %%
soup.find('h2').findNextSibling()
# Out:
# <p>Texto de conteúdo A</p>

# %%
soup.find('h2').findPreviousSibling()
# Out:
# <h1>Título A</h1>

# %%
soup.find('p').findPreviousSiblings()
# Out:
# [<h2 class="ref-a">Sub título A</h2>, <h1>Título A</h1>]

# %%
soup.find('h2').findNext()
# Out:
# <p>Texto de conteúdo A</p>

# %%
soup.find('h2').findPrevious()
# Out:
# <h1>Título A</h1>

# %%
soup.find('h2').findAllNext()
# Out:
# [<p>Texto de conteúdo A</p>,
#  <div id="container-b">
#  <h1>Título B</h1>
#  <h2 class="ref-b">Sub título B</h2>
#  <p>Texto de conteúdo B</p>
#  </div>,
#  <h1>Título B</h1>,
#  <h2 class="ref-b">Sub título B</h2>,
#  <p>Texto de conteúdo B</p>]
